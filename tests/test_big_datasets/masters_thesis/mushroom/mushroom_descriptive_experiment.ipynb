# %%
import numpy as np
from briefcase.case import Case
from briefcase.case_base import CaseBase
import pandas as pd
import matplotlib.pyplot as plt
import MushroomsConverter as MC
import seaborn as sns
import random
import big_dataset_utility.utils as BD

# %% [markdown]
# # Initial Stats

# %%
data = MC.get_existing_test_data(test_split=0.75)
initial_cases = [Case.from_dict(c) for c in data]
initial_cb = CaseBase(initial_cases)
initial_cb.metrics()
# Out:
# Loaded data successfully from 'data/mushrooms-corr-test-0.75.yaml'
# Number of cases:  6093
# Number of cases associated with inconsistency:  42
# Maximum number of edges on a pi case: 302231454903640113807360
# Maximum number of edges on a delta case: 302231454894861200654336
# Factors for pi: 35
# Factors for delta: 44
# (6093, 42)

# %%
filtered_median = BD.filter_data_by_power(data, 5e-11)
CaseBase([Case.from_dict(c) for c in filtered_median]).metrics()
# Out:
# Number of cases:  4118
# Number of cases associated with inconsistency:  0
# Maximum number of edges on a pi case: 1180591620700231434240
# Maximum number of edges on a delta case: 1180591620683051565056
# Factors for pi: 35
# Factors for delta: 36
# (4118, 0)

# %% [markdown]
# ### Starting from an empty casebase how many admissions before we get an inconsistent set?
# Too many cases! Not a good idea to run this

# %%
# _, _, _, _, _, _ = BD.test_admit_bf_incons(BD.balanced_shuffle_data(data, 51))

# %%
# _, _, _, _, _, _ = BD.test_admit_bf_incons(BD.balanced_shuffle_data(filtered_median, 51))

# %% [markdown]
# # Factors

# %%
BD.factors_descriptive_stats(data)
# Out:
# Number of cases with an empty factorset side 0 which are filtered out

# %%
BD.factors_descriptive_stats(filtered_median)
# Out:
# Number of cases with an empty factorset side 0 which are filtered out

# %% [markdown]
# # Power Experiment

# %%
BD.display_case_powers(data, "Mushroom")
# Out:
# Median is 0.011828449328449328% of max dataset power
# Q1 is 9.240976037851046e-06% of max dataset power
# Q2 is 0.002880799755799756% of max dataset power
# Q3 is 0.024405715811965812% of max dataset power
# Q4 is 0.7765567765567766% of max dataset power
# Mean is 3.4536272996252815% of max dataset power
#
# Median is 4.4053649617127465e-11% of max theoretical pi winning power
# Q1 is 3.441691376338086e-14% of max theoretical pi winning power
# Q2 is 1.072919530997782e-11% of max theoretical pi winning power
# Q3 is 9.08961794721134e-11% of max theoretical pi winning power
# Q4 is 2.892193151637994e-09% of max theoretical pi winning power
# Mean is 1.2862623218066736e-08% of max theoretical pi winning power
#
# Median is 4.405364961840834e-11% of max theoretical delta winning power
# Q1 is 3.441691376438155e-14% of max theoretical delta winning power
# Q2 is 1.0729195310289773e-11% of max theoretical delta winning power
# Q3 is 9.089617947475624e-11% of max theoretical delta winning power
# Q4 is 2.8921931517220857e-09% of max theoretical delta winning power
# Mean is 1.2862623218440723e-08% of max theoretical max_delta winning power

# %%
# Median is 
BD.display_case_powers(BD.filter_data_by_power(data, 5e-11))
# Out:
# Median is 0.19235466536394724% of max dataset power
# Q1 is 0.0032059110893991236% of max dataset power
# Q2 is 0.09281875915974597% of max dataset power
# Q3 is 0.764533463605276% of max dataset power
# Q4 is 6.213971665852467% of max dataset power
# Mean is 8.88671265974337% of max dataset power
#
# Median is 1.119104808826229e-11% of max theoretical pi winning power
# Q1 is 1.86517468137705e-13% of max theoretical pi winning power
# Q2 is 5.400124791796408e-12% of max theoretical pi winning power
# Q3 is 4.447997525874408e-11% of max theoretical pi winning power
# Q4 is 3.615241439560542e-10% of max theoretical pi winning power
# Mean is 5.170221815706344e-10% of max theoretical pi winning power
#
# Median is 1.119104808854728e-11% of max theoretical delta winning power
# Q1 is 1.8651746814245485e-13% of max theoretical delta winning power
# Q2 is 5.4001247919339265e-12% of max theoretical delta winning power
# Q3 is 4.447997525987681e-11% of max theoretical delta winning power
# Q4 is 3.615241439652607e-10% of max theoretical delta winning power
# Mean is 5.170221815838008e-10% of max theoretical max_delta winning power
